# %% [markdown]
# ## 2주차 연습문제 입니다

# %% [markdown]
# ### 1번 문제입니다
# - 정사각형의 면적을 구하기 위하여 사용자로부터 밑변의 길이를 정수로 입력받아서 다음과 같이 출력하시오(힌트: int(input(‘정사각형의 밑변을 입력하시오 : ‘))를 사용함).

# %%
sqaure_lenth=int(input('정사각형의 밑변을 입력하시오 :'))
sqaure_area=sqaure_lenth**2
print('정사각형의 면적 :',sqaure_area)
# Out:
# 정사각형의 밑변을 입력하시오 :40
# 정사각형의 면적 : 1600

# %% [markdown]
# ### 2번 문제입니다
# - 섭씨온도(celsius)를 화씨온도(fahrenheit)로 변환하는 식을 바탕으로 사용자로부터 섭씨온도를 입력받아서 다음과 같이 화씨온도로 출력하시오(힌트: int(input(‘섭씨온도를 입력하세요 : ‘))를 사용함).

# %%
celsius=int(input('섭씨온도를 입력하세요 :'))
fahr = (9/5)*celsius+32
print('섭씨 ',celsius,'도는 화씨',str(fahr) + '도 입니다.')
# Out:
# 섭씨온도를 입력하세요 :16
# 섭씨  16 도는 화씨 60.8도 입니다.

# %% [markdown]
# ### 3번 문제입니다
# - 비트 이동 연산자를 이용하여 2의 거듭제곱 수 10개를 다음과 같이 출력하라.
# - 힌트: 2 << 0 = 2, 2 << 1 = 4, 2 << 2 = 8

# %%
print(2<<0,2<<1,2<<2,2<<3,2<<4,2<<5,2<<6,2<<7,2<<8,2<<9)
# Out:
# 2 4 8 16 32 64 128 256 512 1024

# %% [markdown]
# ### 4번 문제입니다
# - 사용자의 키보드 입력을 통해 n값을 입력받아, 주어진 정수 n이 짝수이면 True, 홀수이면 False를 출력하는 코드를 작성해 보라. n이 20, 21인 경우에 대하여 다음과 같이 출력된다.

# %%
n= int(input('정수를 입력하세요 : '))
check=False
if n%2==0:
    check=True
print('이 수가 짝수인가요?',check)
# Out:
# 정수를 입력하세요 : 21
# 이 수가 짝수인가요? False

# %% [markdown]
# ### 5번 문제입니다
# - 사용자로부터 세 자리 정수를 입력으로 받으시오. 이때 입력받은 정수 n에 대한 백의 자리, 십의 자리, 일의 자리 십진수 값을 다음과 같이 출력하시오.
# - 힌트: // 연산자와 % 연산자를 사용하시오. 예를 들어 백의 자리는 n//100을 통해서 구할 수 있다.

# %%
num=int(input('세 자리 정수를 입력하세요 : '))
print('백의 자리 :',num//100)
print('십의 자리 :',num%100//10)
print('일의 자리 :',num%10)
# Out:
# 세 자리 정수를 입력하세요 : 349
# 백의 자리 : 3
# 십의 자리 : 4
# 일의 자리 : 9
