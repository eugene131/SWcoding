# %% [markdown]
# LAB 6

# %% [markdown]
# Lab 6-1

# %%
capital_dic={'Korea':'Seoul','China':'Beijing','USA':'Washington DC'}
print(capital_dic['Korea'])
print(capital_dic['China'])
print(capital_dic['USA'])
# Out:
# Seoul
# Beijing
# Washington DC

# %%
fruits_dic ={'apple':5000,'banana':4000,'grape':5300,'melon':6500}
print(list(fruits_dic.keys())[0]+'의 가격은',str(fruits_dic['apple'])+'원입니다')
print(list(fruits_dic.keys())[1]+'의 가격은',str(fruits_dic['banana'])+'원입니다')
print(list(fruits_dic.keys())[2]+'의 가격은',str(fruits_dic['grape'])+'원입니다')
print(list(fruits_dic.keys())[3]+'의 가격은',str(fruits_dic['melon'])+'원입니다')
# Out:
# apple의 가격은 5000원입니다
# banana의 가격은 4000원입니다
# grape의 가격은 5300원입니다
# melon의 가격은 6500원입니다

# %% [markdown]
# Lab 6-2

# %%
person = {'이름':'홍길동','나이':26,'몸무게':82}
person['특기']='분신술'
person
# Out:
# {'이름': '홍길동', '나이': 26, '몸무게': 82, '특기': '분신술'}

# %%
person['아버지']='홍판서'
person
# Out:
# {'이름': '홍길동', '나이': 26, '몸무게': 82, '특기': '분신술', '아버지': '홍판서'}

# %%
del person['나이']
person
# Out:
# {'이름': '홍길동', '몸무게': 82, '특기': '분신술', '아버지': '홍판서'}

# %% [markdown]
# Lab 6-3

# %%
capital_dic={'Korea':'Seoul','China':'Beijing','USA':'Washington DC'}
print('Korea' in capital_dic)
print('China' in capital_dic)
print('Indonesia' in capital_dic)
print('Beijing'in capital_dic)
# Out:
# True
# True
# False
# False

# %% [markdown]
# Lab 6-4

# %%
fruits_dic ={'apple':6000,'melon':3000,'banana':5000,'orange':7000}
print(fruits_dic.keys())
print(fruits_dic.values())
print(fruits_dic.pop('apple'))
fruits_dic.clear
# Out:
# dict_keys(['apple', 'melon', 'banana', 'orange'])
# dict_values([6000, 3000, 5000, 7000])
# 6000
# <function dict.clear>

# %% [markdown]
# Lab 6-5

# %%
fruits_dic ={'apple':6000,'melon':3000,'banana':5000,'orange':4000}
list(fruits_dic.keys())
# Out:
# ['apple', 'melon', 'banana', 'orange']

# %%
list(fruits_dic.values())
# Out:
# [6000, 3000, 5000, 4000]

# %%
print('fruits_dic의 딕셔너리 항목의 개수 :',len(fruits_dic))
# Out:
# fruits_dic의 딕셔너리 항목의 개수 : 4

# %%
ap='apple'
man='mango'
if ap in fruits_dic:
    print(ap+' is in fruits_dic.')
else:
    print(ap+' is not in fruits_dic.')
if man in fruits_dic:
    print(man+' is in fruits_dic.')
else:
    print(man+' is not in fruits_dic.')
# Out:
# apple is in fruits_dic.
# mango is not in fruits_dic.

# %% [markdown]
# Lab 6-6

# %%
the_day=(1919,3,1)
year,month,day=the_day
print(str(year)+"년 "+str(month)+"월 "+str(day) +"일은 삼일절입니다.")
# Out:
# 1919년 3월 1일은 삼일절입니다.

# %%
s=[10,20,30]
c,b,a=tuple(s)
print('a =',a,'\nb =',b,'\nc =',c)
# Out:
# a = 30
# b = 20
# c = 10

# %% [markdown]
# Lab 6-9

# %%
lst=['apple','mango','banana']
s1=set(lst)
s1
# Out:
# {'apple', 'banana', 'mango'}

# %%
greet='Good afternoon'
s2=set(greet)
s2
# Out:
# {' ', 'G', 'a', 'd', 'e', 'f', 'n', 'o', 'r', 't'}

# %% [markdown]
# Lab 6-10

# %%
s1={10,20,30,40}
s2={30,40,50,60,70}
print(s1|s2)
print(s1&s2)
print(s1-s2)
print(s1^s2)
print(s1.issubset(s2))
print(s1.issuperset(s2))
print(s1.isdisjoint(s2))
# Out:
# {70, 40, 10, 50, 20, 60, 30}
# {40, 30}
# {10, 20}
# {50, 20, 70, 10, 60}
# False
# False
# False
